# %%
import pandas as pd
df = pd.read_csv('Bikes sales.csv')
df
# Out:
#          ID Marital Status Gender      Income  Children            Education  \
# 0     12496              M      F  $40,000.00         1            Bachelors
# 1     24107              M      M  $30,000.00         3      Partial College
# 2     14177              M      M  $80,000.00         5      Partial College
# 3     24381              S      M  $70,000.00         0            Bachelors
# 4     25597              S      M  $30,000.00         0            Bachelors
# ...     ...            ...    ...         ...       ...                  ...
# 1021  16466              S      F  $20,000.00         0  Partial High School
# 1022  19273              M      F  $20,000.00         2      Partial College
# 1023  22400              M      M  $10,000.00         0      Partial College
# 1024  20942              S      F  $20,000.00         0          High School
# 1025  18484              S      M  $80,000.00         2          High School
#
# ...

# %%
df['Marital Status'] = df['Marital Status'].replace({'M': 'Married', 'S': 'Single'})

df
# Out:
#          ID Marital Status Gender      Income  Children            Education  \
# 0     12496        Married      F  $40,000.00         1            Bachelors
# 1     24107        Married      M  $30,000.00         3      Partial College
# 2     14177        Married      M  $80,000.00         5      Partial College
# 3     24381         Single      M  $70,000.00         0            Bachelors
# 4     25597         Single      M  $30,000.00         0            Bachelors
# ...     ...            ...    ...         ...       ...                  ...
# 1021  16466         Single      F  $20,000.00         0  Partial High School
# 1022  19273        Married      F  $20,000.00         2      Partial College
# 1023  22400        Married      M  $10,000.00         0      Partial College
# 1024  20942         Single      F  $20,000.00         0          High School
# 1025  18484         Single      M  $80,000.00         2          High School
#
# ...

# %%
df[['Marital Status','Purchased Bike']]
# Out:
#      Marital Status Purchased Bike
# 0           Married             No
# 1           Married             No
# 2           Married             No
# 3            Single            Yes
# 4            Single            Yes
# ...             ...            ...
# 1021         Single            Yes
# 1022        Married             No
# 1023        Married            Yes
# 1024         Single             No
# 1025         Single            Yes
#
# [1026 rows x 2 columns]

# %%
df[['Marital Status','Purchased Bike']].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df[['Marital Status','Children','Purchased Bike']]
# Out:
#      Marital Status  Children Purchased Bike
# 0                 M         1             No
# 1                 M         3             No
# 2                 M         5             No
# 3                 S         0            Yes
# 4                 S         0            Yes
# ...             ...       ...            ...
# 1021              S         0            Yes
# 1022              M         2             No
# 1023              M         0            Yes
# 1024              S         0             No
# 1025              S         2            Yes
#
# [1026 rows x 3 columns]

# %%
df[['Children','Purchased Bike']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Children,Purchased Bike'>

# %%
df[[ 'Income','Purchased Bike']]
# Out:
#           Income Purchased Bike
# 0     $40,000.00             No
# 1     $30,000.00             No
# 2     $80,000.00             No
# 3     $70,000.00            Yes
# 4     $30,000.00            Yes
# ...          ...            ...
# 1021  $20,000.00            Yes
# 1022  $20,000.00             No
# 1023  $10,000.00            Yes
# 1024  $20,000.00             No
# 1025  $80,000.00            Yes
#
# [1026 rows x 2 columns]

# %%
df.rename(columns={'Income':'Annual_Income'},inplace=True)
df.sort_values(by='Annual_Income', ascending=True, inplace=True)
df
# Out:
#         ID Marital Status Gender Annual_Income  Children            Education  \
# 364  19305         Single      F    $10,000.00         2          High School
# 435  29447         Single      F    $10,000.00         2            Bachelors
# 483  15450        Married      M    $10,000.00         1      Graduate Degree
# 61   19291         Single      F    $10,000.00         2          High School
# 60   24185         Single      F    $10,000.00         1          High School
# ..     ...            ...    ...           ...       ...                  ...
# 963  16007        Married      F    $90,000.00         5            Bachelors
# 191  26944         Single      M    $90,000.00         2          High School
# 185  15799        Married      F    $90,000.00         1            Bachelors
# 329  12663        Married      F    $90,000.00         5  Partial High School
# 480  18294        Married      F    $90,000.00         1            Bachelors
#
# ...

# %%
df[['Annual_Income','Purchased Bike']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Annual_Income,Purchased Bike'>

# %%
df[['Marital Status','Children','Purchased Bike']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Marital Status,Children,Purchased Bike'>

# %%
df[['Marital Status','Children','Purchased Bike']]
# Out:
#     Marital Status  Children Purchased Bike
# 364         Single         2            Yes
# 435         Single         2             No
# 483        Married         1             No
# 61          Single         2             No
# 60          Single         1             No
# ..             ...       ...            ...
# 963        Married         5            Yes
# 191         Single         2            Yes
# 185        Married         1            Yes
# 329        Married         5             No
# 480        Married         1             No
#
# [1026 rows x 3 columns]

# %%
df[['Annual_Income','Purchased Bike']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Annual_Income,Purchased Bike'>

# %%
df[['Children','Home Owner','Purchased Bike']]
# Out:
#      Children Home Owner Purchased Bike
# 364         2        Yes            Yes
# 435         2         No             No
# 483         1        Yes             No
# 61          2        Yes             No
# 60          1         No             No
# ..        ...        ...            ...
# 963         5        Yes            Yes
# 191         2        Yes            Yes
# 185         1        Yes            Yes
# 329         5        Yes             No
# 480         1        Yes             No
#
# [1026 rows x 3 columns]

# %%
df[['Children','Home Owner','Purchased Bike']].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Children,Home Owner,Purchased Bike'>

# %%
df[['Occupation','Purchased Bike']]
# Out:
#          Occupation Purchased Bike
# 364          Manual            Yes
# 435        Clerical             No
# 483        Clerical             No
# 61           Manual             No
# 60           Manual             No
# ..              ...            ...
# 963      Management            Yes
# 191          Manual            Yes
# 185    Professional            Yes
# 329  Skilled Manual             No
# 480    Professional             No
#
# [1026 rows x 2 columns]

# %%
df[['Occupation','Purchased Bike']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Occupation,Purchased Bike'>

# %%
df[['Children','Cars','Purchased Bike']]
# Out:
#      Children  Cars Purchased Bike
# 364         2     1            Yes
# 435         2     1             No
# 483         1     0             No
# 61          2     0             No
# 60          1     1             No
# ..        ...   ...            ...
# 963         5     2            Yes
# 191         2     0            Yes
# 185         1     1            Yes
# 329         5     2             No
# 480         1     1             No
#
# [1026 rows x 3 columns]

# %%
df[['Cars','Purchased Bike']]
# Out:
#      Cars Purchased Bike
# 364     1            Yes
# 435     1             No
# 483     0             No
# 61      0             No
# 60      1             No
# ..    ...            ...
# 963     2            Yes
# 191     0            Yes
# 185     1            Yes
# 329     2             No
# 480     1             No
#
# [1026 rows x 2 columns]

# %%
df[['Cars','Purchased Bike']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Cars,Purchased Bike'>

# %%
df[['Region','Purchased Bike']]
# Out:
#        Region Purchased Bike
# 0      Europe             No
# 1      Europe             No
# 2      Europe             No
# 3     Pacific            Yes
# 4      Europe            Yes
# ...       ...            ...
# 1021   Europe            Yes
# 1022   Europe             No
# 1023  Pacific            Yes
# 1024   Europe             No
# 1025  Pacific            Yes
#
# [1026 rows x 2 columns]

# %%
df[['Region','Purchased Bike']].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df[['Commute Distance','Purchased Bike']]
# Out:
#     Commute Distance Purchased Bike
# 364        0-1 Miles            Yes
# 435        2-5 Miles             No
# 483        0-1 Miles             No
# 61         0-1 Miles             No
# 60         1-2 Miles             No
# ..               ...            ...
# 963        1-2 Miles            Yes
# 191        0-1 Miles            Yes
# 185        2-5 Miles            Yes
# 329        10+ Miles             No
# 480       5-10 Miles             No
#
# [1026 rows x 2 columns]

# %%
df[['Commute Distance','Purchased Bike']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Commute Distance,Purchased Bike'>

# %%
df[['Gender','Purchased Bike']]
# Out:
#     Gender Purchased Bike
# 364      F            Yes
# 435      F             No
# 483      M             No
# 61       F             No
# 60       F             No
# ..     ...            ...
# 963      F            Yes
# 191      M            Yes
# 185      F            Yes
# 329      F             No
# 480      F             No
#
# [1026 rows x 2 columns]

# %%
df[['Gender','Purchased Bike']].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Gender,Purchased Bike'>
